# %% [markdown]
# ### 1. **Sözlük Tanımlama**
#
# Bir sözlük, Python'da `{key: value}` biçiminde tanımlanır. İşte basit bir sözlük tanımlama örneği:
#
# ```python
# # Sözlük Tanımlama
# person = {
#     "isim": "Erhan",
#     "yaş": 30,
#     "meslek": "Öğretim Görevlisi"
# }
#
# print(person)
# ```
#
# **Çıktı:**
# ```python
# {'isim': 'Erhan', 'yaş': 30, 'meslek': 'Öğretim Görevlisi'}
# ```
#
# ---
#
# ### 2. **Sözlük Üreteçleri (Dictionary Comprehension)**
#
# Sözlük üreteçleri (dictionary comprehension) ile bir sözlüğü daha kısa ve etkili bir şekilde oluşturabilirsiniz. Örneğin, her bir kelimeyi ve anlamını alarak bir sözlük oluşturmak için:
#
# ```python
# # Sözlük Üreteci ile Sözlük Oluşturma
# words = ['apple', 'banana', 'cherry', 'date']
# meanings = ['A fruit', 'A fruit', 'A fruit', 'A fruit']
#
# # Dictionary comprehension
# word_dict = {word: meaning for word, meaning in zip(words, meanings)}
#
# print(word_dict)
# ```
#
# **Çıktı:**
# ```python
# {'apple': 'A fruit', 'banana': 'A fruit', 'cherry': 'A fruit', 'date': 'A fruit'}
# ```
#
# ---
#
# ### 3. **📌 Bölüm Sonu Uygulaması: Kullanıcının Girdiği Kelimeler ve Anlamlarını İçeren Bir Sözlük Oluşturun**
#
# Kullanıcının girdiği kelimeler ve anlamlarını içeren bir sözlük oluşturabiliriz. Kullanıcıdan veri alarak bu veriyi bir sözlükte saklayacağız:
#
# ```python
# # Bölüm Sonu Uygulaması: Kullanıcıdan Kelime ve Anlamları Almak
#
# dictionary = {}
#
# # Kullanıcıdan kelime ve anlamları al
# while True:
#     word = input("Bir kelime girin (çıkmak için 'q' yazın): ")
#     if word.lower() == 'q':
#         break
#     meaning = input(f"{word} kelimesinin anlamını girin: ")
#     dictionary[word] = meaning
#
# print("\nOluşan Sözlük:")
# print(dictionary)
# ```
#
# **Çıktı:**
# ```
# Bir kelime girin (çıkmak için 'q' yazın): elma
# elma kelimesinin anlamını girin: Ağaçta yetişen kırmızı meyve
# Bir kelime girin (çıkmak için 'q' yazın): q
# Oluşan Sözlük:
# {'elma': 'Ağaçta yetişen kırmızı meyve'}
# ```
#
# ---
